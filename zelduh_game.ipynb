# %% [markdown]
# <a href="https://colab.research.google.com/github/isaias55/python_projects/blob/main/zelduh_game.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print('''
*******************************************************************************
─────────────────────────────
─────────────███─────────────
────────────█████────────────
───────────███████───────────
──────────█████████──────────
─────────███████████─────────
────────█████████████────────
───────███████████████─────── The Legend of Zelduh
──────███───────────███──────
─────█████─────────█████─────
────███████───────███████────
───█████████─────█████████───
──███████████───███████████──
─█████████████▄█████████████─

*******************************************************************************
''')
print("Welcome to The Legend of Zelduh.")
print("Your mission is to find and rescue the princess Zelduh.")
answer1 = input("Which side would you like to start off your journey?\nLeft or Right: ").lower()
if answer1 == "right":
  print("You have met a terrible fate haven't you?\nGAME OVER") 
elif answer1 == "left":
  answer2 = input("Great! Would you like to swim towards the shore or wait for pirates to pass?\nSwim or Wait: ").lower()
  if answer2 == "swim":
    print("You have met a terrible fate haven't you?\nGAME OVER")
  elif answer2 == "wait":
    answer3 = input("You are one step closer to rescuing the princess! Which door would you like to chose?\nRed, Blue, Yellow: ").lower()
    if answer3 == "red":
      print("You have met a terrible fate haven't you?\nGAME OVER")
    elif answer3 =="blue":
      print("You have met a terrible fate haven't you?\nGAME OVER")
    elif answer3 == "yellow":
      print("You have rescued the princess Zelduh! Congrats!")
      print("""
                                              ::
                                             ::
                                             ::
                                            ::
                                            ::
                              __           ::
   _..-'/-¯¯--/_          ,.--. ''.     |`\=,.. 
-:--.---''-..  /_         |\\_\..  \    `-.=._/
.-|¯         '.  \         \_ \-`/\ |    ::`
  /  @  \      \  -_   _..--|-\¯¯``'--.-/_\
  |   .-'|      \  \\-'\_/     ¯/-.|-.\_\_/
  \_./` /        \_//-''/    .-'
       |           '-/'@====/              _.--.
   __.'             /¯¯'-. \-'.          _/   /¯'
.''____|   /       |'--\__\/-._        .'    |
 \ \_. \  |       _| -/        \-.__  /     /
  \___\ '/   _.  ('-..| /       '_  ''   _.'
        /  .'     ¯¯¯¯ /        | ``'--''
       (  / ¯```¯¯¯¯¯|-|        |
        \ \_.         \ \      /  
         \___\         '.'.   /
                         /    |
                        /   .'
                       /  .' |
                     .'  / \  \
                    /___| /___'""")
# Out:
# *******************************************************************************
# ─────────────────────────────
# ─────────────███─────────────
# ────────────█████────────────
# ───────────███████───────────
# ──────────█████████──────────
# ─────────███████████─────────
# ────────█████████████────────
# ───────███████████████─────── The Legend of Zelduh
# ──────███───────────███──────
# ─────█████─────────█████─────
# ────███████───────███████────
# ───█████████─────█████████───
# ──███████████───███████████──
# ─█████████████▄█████████████─
#
# *******************************************************************************
#
# Welcome to The Legend of Zelduh.
# Your mission is to find and rescue the princess Zelduh.
# Which side would you like to start off your journey?
# Left or Right: left
# Great! Would you like to swim towards the shore or wait for pirates to pass?
# Swim or Wait: wait
# You are one step closer to rescuing the princess! Which door would you like to chose?
# ...
